# %%
# Workflow Order:
# 1. 01_data_generator
# 2. 02_ingestion_bronze
# 3. 03_silver_transformation
# 4. 04_gold_kpis
# 5. 05_dashboard_queries

# %%
from datetime import datetime

print("Workflow started at:", datetime.now())
# Out:
# Workflow started at: 2026-05-28 08:09:17.414646

# %%
print("Enterprise Lakehouse Pipeline Executed Successfully")
# Out:
# Enterprise Lakehouse Pipeline Executed Successfully
